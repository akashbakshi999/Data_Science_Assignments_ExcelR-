# %% [markdown]
# ## Basic stats 1

# %%
#pip install pandas

# %%
import pandas as pd
import numpy as np
import scipy as sp

# %%
df = pd.read_csv("sales_data_with_discounts.csv")

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.isnull().sum()
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
from scipy import stats

# %%
# Identify numerical columns
numerical_columns = df.select_dtypes(include=['number']).columns
print("Numerical Columns:", numerical_columns)
# Out:
# Numerical Columns: Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# Calculating the mean, median, mode, and standard deviation for each numerical column
for column in numerical_columns:
    print(f"Statistics for {column}:")
    print(f"  Mean: {df[column].mean()}")
    print(f"  Median: {df[column].median()}")
    print(f"  Mode: {df[column].mode()[0]}")  # mode() returns a series, take the first value
    print(f"  Standard Deviation: {df[column].std()}")
    print("-" * 40)
# Out:
# Statistics for Volume:
#   Mean: 5.066666666666666
#   Median: 4.0
#   Mode: 3
#   Standard Deviation: 4.231602391213926
# ----------------------------------------
# Statistics for Avg Price:
#   Mean: 10453.433333333332
#   Median: 1450.0
#   Mode: 400
#   Standard Deviation: 18079.90483993645
# ----------------------------------------
# Statistics for Total Sales Value:
#   Mean: 33812.83555555555
#   Median: 5700.0
#   Mode: 24300
#   Standard Deviation: 50535.07417255328
# ----------------------------------------
# Statistics for Discount Rate (%):
#   Mean: 15.155241895330914
#   Median: 16.57776564929597
#   Mode: 5.007822189204133
#   Standard Deviation: 4.220602153325511
# ----------------------------------------
# Statistics for Discount Amount:
#   Mean: 3346.499424342415
#   Median: 988.9337332382784
#   Mode: 69.17794228822787
#   Standard Deviation: 4509.9029633539985
# ----------------------------------------
# Statistics for Net Sales Value:
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 8))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(2, 3, i)  # Adjust number of rows and columns for your columns
    sns.histplot(df[column], kde=True, bins=15)
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, palette="Set2")

# Title and Labels
plt.title('Boxplots of Numerical Variables')
plt.ylabel('Values')
plt.xticks(rotation=45)

plt.show()

# %%
# Identified categorical columns
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
print("Categorical Columns:", categorical_columns)
# Out:
# Categorical Columns: Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
# Plot style
sns.set(style="whitegrid")

# Plot bar charts for categorical columns
for col in categorical_columns:
    plt.figure(figsize=(10, 8))
    sns.countplot(data=df, x=col, hue=col, palette="Set2", legend=False)
    plt.title(f'Frequency of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Display first few rows before standardization
print("Before Standardization:\n", df.head())
# Out:
# Before Standardization:
#           Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# ...

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Applied standardization
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# Display first few rows after standardization
print("After Standardization:\n", df.head())
# Out:
# After Standardization:
#           Date       Day  SKU City    Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C  2.350029  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C  1.167129  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C  0.457388  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C  0.220808  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C -0.488932  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0   0.091173           2.925721          -0.830289         3.952816
# 1  -0.019570           1.330995          -0.852661         1.849014
# 2   0.312659           1.562775          -1.351631         1.622995
# 3   0.534146           1.719276          -1.949723         1.113807
# 4  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value
# 0         2.804756
# 1         1.271026
# 2         1.545675
# ...

# %%
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#             Date       Day  SKU City    Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C  2.350029    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C  1.167129    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C  0.457388    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C  0.220808    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C -0.488932    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...       ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C -0.725512  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  0.220808  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C -0.725512  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C -0.488932  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C -0.962092  Lifestyle  Jeera     M-Shoes
#
# ...

# %%
# Applied one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Brand'], drop_first=True)

print("One-Hot Encoded DataFrame:\n", df_encoded)
# Out:
# One-Hot Encoded DataFrame:
#             Date       Day  SKU City    Volume         BU       Model  \
# 0    01-04-2021  Thursday  M01    C  2.350029    Mobiles       RU-10
# 1    01-04-2021  Thursday  M02    C  1.167129    Mobiles   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C  0.457388    Mobiles       YM-99
# 3    01-04-2021  Thursday  M04    C  0.220808    Mobiles  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C -0.488932    Mobiles      YM-98
# ..          ...       ...  ...  ...       ...        ...         ...
# 445  15-04-2021  Thursday  L06    C -0.725512  Lifestyle   M-Casuals
# 446  15-04-2021  Thursday  L07    C  0.220808  Lifestyle   W-Western
# 447  15-04-2021  Thursday  L08    C -0.725512  Lifestyle    W-Lounge
# 448  15-04-2021  Thursday  L09    C -0.488932  Lifestyle   M-Formals
# 449  15-04-2021  Thursday  L10    C -0.962092  Lifestyle     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
# Conclusion

print("\nConclusion:")
print("- Descriptive analytics revealed key statistics and distributions.")
print("- Visualizations showed data trends, skews, and outliers.")
print("- Standardization was applied to ensure uniform scale across numerical features.")
print("- Categorical variables were successfully encoded for modeling purposes.")
# Out:
# Conclusion:
# - Descriptive analytics revealed key statistics and distributions.
# - Visualizations showed data trends, skews, and outliers.
# - Standardization was applied to ensure uniform scale across numerical features.
# - Categorical variables were successfully encoded for modeling purposes.
